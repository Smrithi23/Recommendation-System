# %%
# UPCSim MAE

import numpy as np
import matplotlib.pyplot as plt
data = [[0.8150, 0.7975, 0.7886, 0.7829, 0.7797],
[0.8059, 0.7882, 0.7806, 0.7755, 0.7712],
[0.7996, 0.7839, 0.7759, 0.7703, 0.7661],
[0.7987, 0.7798, 0.7724, 0.7674, 0.7639],
[0.7991, 0.7838, 0.7758, 0.7712, 0.7680]]
X = np.arange(5)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xlabel("k value")
plt.ylabel("RMSE")
plt.xticks([r + 0.25 for r in range(5)],
        ['20', '40', '60', '80', '100'])
plt.ylim(0.75, 0.85)
plot_1 = ax.bar(X + 0.00, data[0], color = 'b', width = 0.15)
plot_2 = ax.bar(X + 0.15, data[1], color = 'g', width = 0.15)
plot_3 = ax.bar(X + 0.30, data[2], color = 'r', width = 0.15)
plot_4 = ax.bar(X + 0.45, data[3], color = 'cyan', width = 0.15)
plot_5 = ax.bar(X + 0.60, data[4], color = 'y', width = 0.15)
ax.legend([plot_1, plot_2, plot_3, plot_4, plot_5], ['train 1', 'train 2', 'train 3', 'train 4', 'train 5'])
plt.title("UPCSim - MAE values")
plt.savefig("./pics/upcsim_mae.png", bbox_inches='tight')

# %%
# UPCSim RMSE

import numpy as np
import matplotlib.pyplot as plt
data = [[1.0269, 1.0063, 0.9968, 0.9907, 0.9872],
[1.0172, 0.9953, 0.9877, 0.9822, 0.9779],
[1.0098, 0.9911, 0.9818, 0.9756, 0.9710],
[1.0049, 0.9849, 0.9765, 0.9708, 0.9672],
[1.0033, 0.9847, 0.9758, 0.9707, 0.9675]]
X = np.arange(5)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xlabel("k value")
plt.ylabel("RMSE")
plt.xticks([r + 0.25 for r in range(5)],
        ['20', '40', '60', '80', '100'])
plt.ylim(0.9, 1.1)
plot_1 = ax.bar(X + 0.00, data[0], color = 'b', width = 0.15)
plot_2 = ax.bar(X + 0.15, data[1], color = 'g', width = 0.15)
plot_3 = ax.bar(X + 0.30, data[2], color = 'r', width = 0.15)
plot_4 = ax.bar(X + 0.45, data[3], color = 'cyan', width = 0.15)
plot_5 = ax.bar(X + 0.60, data[4], color = 'y', width = 0.15)
ax.legend([plot_1, plot_2, plot_3, plot_4, plot_5], ['train 1', 'train 2', 'train 3', 'train 4', 'train 5'])
plt.title("UPCSim - RMSE values")
plt.savefig("./pics/upcsim_rmse.png", bbox_inches='tight')

# %%
# UPCSim Jaccard MAE

import numpy as np
import matplotlib.pyplot as plt
data = [[0.7606, 0.7578, 0.7571, 0.7573, 0.7578],
[0.7563, 0.7519, 0.7514, 0.7517, 0.7523],
[0.7557, 0.7515, 0.7509, 0.7507, 0.7509],
[0.7608, 0.7556, 0.7542, 0.7543, 0.7547],
[0.7790, 0.7738, 0.7728, 0.7729, 0.7731]]
X = np.arange(5)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xlabel("k value")
plt.ylabel("RMSE")
plt.xticks([r + 0.25 for r in range(5)],
        ['20', '40', '60', '80', '100'])
plt.ylim(0.65, 0.85)
plot_1 = ax.bar(X + 0.00, data[0], color = 'b', width = 0.15)
plot_2 = ax.bar(X + 0.15, data[1], color = 'g', width = 0.15)
plot_3 = ax.bar(X + 0.30, data[2], color = 'r', width = 0.15)
plot_4 = ax.bar(X + 0.45, data[3], color = 'cyan', width = 0.15)
plot_5 = ax.bar(X + 0.60, data[4], color = 'y', width = 0.15)
ax.legend([plot_1, plot_2, plot_3, plot_4, plot_5], ['train 1', 'train 2', 'train 3', 'train 4', 'train 5'])
plt.title("UPCSim using Jaccard - RMSE values")
plt.savefig("./pics/upcsim_jaccard_mae.png", bbox_inches='tight')

# %%
# UPCSim Jaccard RMSE

import numpy as np
import matplotlib.pyplot as plt
data = [[0.9675, 0.9624, 0.9618, 0.9621, 0.9630],
[0.9607, 0.9554, 0.9542, 0.9551, 0.9558],
[0.9592, 0.9533, 0.9527, 0.9526, 0.9531],
[0.9583, 0.9529, 0.9515, 0.9520, 0.9526],
[0.9875, 0.9808, 0.9799, 0.9799, 0.9804]]
X = np.arange(5)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xlabel("k value")
plt.ylabel("RMSE")
plt.xticks([r + 0.25 for r in range(5)],
        ['20', '40', '60', '80', '100'])
plt.ylim(0.94, 1)
plot_1 = ax.bar(X + 0.00, data[0], color = 'b', width = 0.15)
plot_2 = ax.bar(X + 0.15, data[1], color = 'g', width = 0.15)
plot_3 = ax.bar(X + 0.30, data[2], color = 'r', width = 0.15)
plot_4 = ax.bar(X + 0.45, data[3], color = 'cyan', width = 0.15)
plot_5 = ax.bar(X + 0.60, data[4], color = 'y', width = 0.15)
ax.legend([plot_1, plot_2, plot_3, plot_4, plot_5], ['train 1', 'train 2', 'train 3', 'train 4', 'train 5'])
plt.title("UPCSim using Jaccard - RMSE values")
plt.savefig("./pics/upcsim_jaccard_rmse.png", bbox_inches='tight')
